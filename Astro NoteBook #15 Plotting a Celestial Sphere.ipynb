# %%
from astropy import units as u

# %%
from astropy.coordinates import SkyCoord

# %%
import numpy as np

# %%
from scipy.special import gammaln

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"]=[40,20]

# %%
from scipy import misc

# %%
from psrqpy import QueryATNF

# %%
query=QueryATNF(params=['P0', 'P1', 'ASSOC', 'SURVEY','RAJ','DECJ'])
# Out:
# WARNING: AstropyDeprecationWarning: In v4.1 and later versions, the Galactocentric frame will adopt default parameters that may update with time. An updated default parameter set is already available through the astropy.coordinates.galactocentric_frame_defaults ScienceState object, as described in but the default is currently still set to the pre-v4.0 parameter defaults. The safest way to guard against changing default parameters in the future is to either (1) specify all Galactocentric frame attributes explicitly when using the frame, or (2) set the galactocentric_frame_defaults parameter set name explicitly. See http://docs.astropy.org/en/latest/coordinates/galactocentric.html for more information. [astropy.coordinates.builtin_frames.galactocentric]

# %%
positive=query.table[query.table['P1']>0]

# %%
psrtable=query.table

# %%
psrtable['coord'] = SkyCoord(psrtable['RAJ'], psrtable['DECJ'], unit=(u.hourangle, u.deg))

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import cm
from collections import OrderedDict

cmaps = OrderedDict()

# %%
Dark2=cm.get_cmap("Dark2")
colors=Dark2.colors
print(colors[0],colors[1])
# Out:
# (0.10588235294117647, 0.6196078431372549, 0.4666666666666667) (0.8509803921568627, 0.37254901960784315, 0.00784313725490196)

# %%
pi = np.pi
deg2rad = pi/180.
ax = plt.figure(figsize=(10, 5))
ax = plt.subplot(111, projection='aitoff')
org=0
tick_xlabels = [r'$150^\circ$', r'$120^\circ$', r'$90^\circ$', r'$60^\circ$', r'$30^\circ$', 
                r'$0^\circ$', r'$330^\circ$', r'$300^\circ$', r'$270^\circ$', r'$240^\circ$', r'$210^\circ$']
ax.set_xticklabels(tick_xlabels)     # we add the scale on the x axis
#plt.set_xlabel(r'$l$')
#plt.xaxis.label.set_fontsize(16)
#plt.set_ylabel(r'$b$')
#plt.yaxis.label.set_fontsize(12)
ax.grid(True)
#plt.plot(x+np.pi/6,y+np.pi/6)
#plt.plot(x-np.pi/2,y-np.pi/2);

# Pass the coordinates in radians, since otherwise the
# aitoff projection messes up:

ax.plot(-1*psrtable['coord'].galactic.l.radian, psrtable['coord'].galactic.b.radian, '.', color='0.5')
ax.plot(2*pi-psrtable['coord'].galactic.l.radian, psrtable['coord'].galactic.b.radian, '.', color='0.5')
plt.grid(True)
plt.text(0,-100*deg2rad,r'$l$',
      ha='center', va='center', fontsize=16)
#plt.xlabel(r'$l$', fontsize=16)
plt.ylabel(r'$b$', fontsize=16)

plt.show()

# %%
ax = plt.figure(figsize=(10, 5))
ax = plt.subplot(111, projection='aitoff')
org=0
tick_xlabels = [r'$10^{\rm h}$', r'$8^{\rm h}$', r'$6^{\rm h}$', r'$4^{\rm h}$', r'$2^{\rm h}$', 
                r'$0^{\rm h}$', r'$22^{\rm h}$', r'$20^{\rm h}$', r'$18^{\rm h}$', r'$16^{\rm h}$', r'$14^{\rm h}$']
ax.set_xticklabels(tick_xlabels)     # we add the scale on the x axis
#plt.set_xlabel(r'$l$')
#plt.xaxis.label.set_fontsize(16)
#plt.set_ylabel(r'$b$')
#plt.yaxis.label.set_fontsize(12)
ax.grid(True)
#plt.plot(x+np.pi/6,y+np.pi/6)
#plt.plot(x-np.pi/2,y-np.pi/2);

# Pass the coordinates in radians, since otherwise the
# aitoff projection messes up:

ax.plot(-1*psrtable['coord'].ra.radian, psrtable['coord'].dec.radian, '.', color='0.5')
ax.plot(2*pi-psrtable['coord'].ra.radian, psrtable['coord'].dec.radian, '.', color='0.5')
plt.grid(True)
plt.text(0,-100*deg2rad,r'R. A.',
      ha='center', va='center', fontsize=16)
#plt.xlabel(r'$l$', fontsize=16)
plt.ylabel(r'Dec', fontsize=16)

plt.show()

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import cm
from collections import OrderedDict

cmaps = OrderedDict()

# %%
Dark2=cm.get_cmap("Dark2")
colors=Dark2.colors
print(colors[0],colors[1])
# Out:
# (0.10588235294117647, 0.6196078431372549, 0.4666666666666667) (0.8509803921568627, 0.37254901960784315, 0.00784313725490196)

# %%
FermiAssoc=psrtable[psrtable['SURVEY']=='FermiAssoc']

# %%
pi = np.pi
deg2rad = pi/180.
ax = plt.figure(figsize=(10, 5))
ax = plt.subplot(111, projection='aitoff')
org=0
tick_xlabels = [r'$150^\circ$', r'$120^\circ$', r'$90^\circ$', r'$60^\circ$', r'$30^\circ$', 
                r'$0^\circ$', r'$330^\circ$', r'$300^\circ$', r'$270^\circ$', r'$240^\circ$', r'$210^\circ$']
ax.set_xticklabels(tick_xlabels)     # we add the scale on the x axis
#plt.set_xlabel(r'$l$')
#plt.xaxis.label.set_fontsize(16)
#plt.set_ylabel(r'$b$')
#plt.yaxis.label.set_fontsize(12)
ax.grid(True)
#plt.plot(x+np.pi/6,y+np.pi/6)
#plt.plot(x-np.pi/2,y-np.pi/2);

# Pass the coordinates in radians, since otherwise the
# aitoff projection messes up:

ax.plot(-1*psrtable['coord'].galactic.l.radian, psrtable['coord'].galactic.b.radian, '.', color=colors[0])
ax.plot(2*pi-psrtable['coord'].galactic.l.radian, psrtable['coord'].galactic.b.radian, '.', color=colors[0])
ax.plot(-1*FermiAssoc['coord'].galactic.l.radian, FermiAssoc['coord'].galactic.b.radian, '.', color=colors[1])
ax.plot(2*pi-FermiAssoc['coord'].galactic.l.radian, FermiAssoc['coord'].galactic.b.radian, '.', color=colors[1])
ax.plot
plt.grid(True)
plt.text(0,-100*deg2rad,r'$l$',
      ha='center', va='center', fontsize=16)
#plt.xlabel(r'$l$', fontsize=16)
plt.ylabel(r'$b$', fontsize=16)

plt.show()

# %%
#Do the same for FermiBlind and FermiAssoc,ghrss with same colors

# %%
#Add a legend to the aitoff projection

# %%
import numpy as np
from astropy.coordinates import SkyCoord
from astropy.table import Column, Table
from astropy.units import Quantity
from gammapy.astro.source import PWN, SNR, Pulsar, SNRTrueloveMcKee
from gammapy.utils import coordinates as astrometry
from gammapy.utils.random import (
    draw,
    get_random_state,
    pdf,
    sample_sphere,
    sample_sphere_distance,)

# %%
#Bring over the color list and make the FermiAssoc Pulsars bigger shapes

# %%
Set1=cm.get_cmap("Set1")
colors=Set1.colors
print(colors[0],colors[1])
# Out:
# (0.8941176470588236, 0.10196078431372549, 0.10980392156862745) (0.21568627450980393, 0.49411764705882355, 0.7215686274509804)

# %%
FermiBlind=psrtable[psrtable['SURVEY']=='FermiBlind']

# %%
pi = np.pi
deg2rad = pi/180.
ax = plt.figure(figsize=(10, 5))
ax = plt.subplot(111, projection='aitoff')
org=0
tick_xlabels = [r'$150^\circ$', r'$120^\circ$', r'$90^\circ$', r'$60^\circ$', r'$30^\circ$', 
                r'$0^\circ$', r'$330^\circ$', r'$300^\circ$', r'$270^\circ$', r'$240^\circ$', r'$210^\circ$']
ax.set_xticklabels(tick_xlabels)     # we add the scale on the x axis
#plt.set_xlabel(r'$l$')
#plt.xaxis.label.set_fontsize(16)
#plt.set_ylabel(r'$b$')
#plt.yaxis.label.set_fontsize(12)
ax.grid(True)
#plt.plot(x+np.pi/6,y+np.pi/6)
#plt.plot(x-np.pi/2,y-np.pi/2);

# Pass the coordinates in radians, since otherwise the
# aitoff projection messes up:

ax.plot(-1*psrtable['coord'].galactic.l.radian, psrtable['coord'].galactic.b.radian, '.', color=colors[0])
ax.plot(2*pi-psrtable['coord'].galactic.l.radian, psrtable['coord'].galactic.b.radian, '.', color=colors[0])
ax.plot(-1*FermiBlind['coord'].galactic.l.radian, FermiBlind['coord'].galactic.b.radian, '.', color=colors[1])
ax.plot(2*pi-FermiBlind['coord'].galactic.l.radian, FermiBlind['coord'].galactic.b.radian, '.', color=colors[1])
ax.plot
plt.grid(True)
plt.text(0,-100*deg2rad,r'$l$',
      ha='center', va='center', fontsize=16)
#plt.xlabel(r'$l$', fontsize=16)
plt.ylabel(r'$b$', fontsize=16)

plt.show()

# %%
tab10=cm.get_cmap("tab10")
colors=tab10.colors
print(colors[0],colors[1])
colors=['grey',colors[1],colors[2],colors[3],colors[4]]
# Out:
# (0.12156862745098039, 0.4666666666666667, 0.7058823529411765) (1.0, 0.4980392156862745, 0.054901960784313725)

# %%
FermiAssocghrss=psrtable[psrtable['SURVEY']=='FermiAssoc,ghrss']

# %%
import numpy as np
from astropy import units as u
from astropy.coordinates import SkyCoord
from gammapy.data import EventList
from gammapy.datasets import MapDataset
from gammapy.datasets.map import MapEvaluator
from gammapy.irf import EnergyDependentTablePSF, PSFMap, EDispMap
from gammapy.maps import Map, MapAxis, WcsNDMap, WcsGeom
from gammapy.modeling.models import (
    PowerLawSpectralModel,
    PointSpatialModel,
    SkyModel,
    SkyDiffuseCube,
    Models,
    create_fermi_isotropic_diffuse_model,
    BackgroundModel,
)
from gammapy.modeling import Fit

# %%
events = EventList.read(
    "$GAMMAPY_DATA/fermi_3fhl/fermi_3fhl_events_selected.fits.gz"
)

# %%
gc_pos = SkyCoord(0, 0, unit="deg", frame="galactic")
energy_axis = MapAxis.from_edges(
    [1e4, 3e4, 1e5, 3e5, 2e6], name="energy", unit="MeV", interp="log"
)
counts = Map.create(
    skydir=gc_pos,
    npix=(3600, 1800),
    proj="AIT",
    frame="galactic",
    binsz=0.1,
    axes=[energy_axis],
    dtype=float,
)
# We put this call into the same Jupyter cell as the Map.create
# because otherwise we could accidentally fill the counts
# multiple times when executing the ``fill_by_coord`` multiple times.
counts.fill_by_coord({"skycoord": events.radec, "energy": events.energy})

# %%
mpl.rcParams.update({'font.size': 24})
_,ax,_=counts.sum_over_axes().smooth(2).plot(stretch="log", vmax=30);
wcs = counts.geom.wcs
#src_pos = SkyCoord.from_name("Sgr A").galactic
src_psrtable=psrtable['coord'].galactic
src_FermiAssocghrss=FermiAssocghrss['coord'].galactic
src_FermiAssoc=FermiAssoc['coord'].galactic
src_FermiBlind=FermiBlind['coord'].galactic
#ax.plot(src_pos.to_pixel(wcs=wcs)[0], src_pos.to_pixel(wcs=wcs)[1],"o", color="red")
ax.plot(src_psrtable.to_pixel(wcs=wcs)[0], src_psrtable.to_pixel(wcs=wcs)[1],".", color="grey",label='Non-FermiPulsars', markersize=10)
ax.plot(src_FermiAssocghrss.to_pixel(wcs=wcs)[0], src_FermiAssocghrss.to_pixel(wcs=wcs)[1],"o", color="lime",label='FermiAssoc,ghrss', markersize=10)
ax.plot(src_FermiAssoc.to_pixel(wcs=wcs)[0], src_FermiAssoc.to_pixel(wcs=wcs)[1],"o", color="magenta",label='FermiAssoc', markersize=10)
ax.plot(src_FermiBlind.to_pixel(wcs=wcs)[0], src_FermiBlind.to_pixel(wcs=wcs)[1],"o", color="cyan",label='FermiBlind', markersize=10)
ax.legend(loc="upper right",fontsize=22)

# %%
m = Map.read("$GAMMAPY_DATA/fermi_3fhl/fermi_3fhl_events_selected.fits.gz")
m.smooth("0.1 deg").plot(cmap="inferno", add_cbar=True, stretch="sqrt")
plt.show()
# Out:
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / world coord. system for this file (FK5 or FK4)
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-REF to '2001-01-01T00:01:04.184' from MJD-REF.
# Set MJD-OBS to 54682.655278 from DATE-OBS.
# Set MJD-END to 57236.967546 from DATE-END'. [astropy.wcs.wcs]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-63f1a14a3b58> in <module>
# ----> 1 m = Map.read("$GAMMAPY_DATA/fermi_3fhl/fermi_3fhl_events_selected.fits.gz")
#       2 m.smooth("0.1 deg").plot(cmap="inferno", add_cbar=True, stretch="sqrt")
#       3 plt.show()
#
# ~/opt/anaconda3/envs/gammapy-0.17/lib/python3.7/site-packages/gammapy/maps/base.py in read(filename, hdu, hdu_bands, map_type)
#     186         """
# ...

# %%
gc_pos = SkyCoord(0, 0, unit="deg", frame="galactic")
energy_axis = MapAxis.from_edges( [1e4, 3e4, 1e5, 3e5, 2e6], name="energy", unit="MeV", interp="log")
counts = Map.create( 
    skydir=gc_pos,   
    npix=(3600, 1800),  proj="AIT",  frame="galactic",    binsz=0.1,    axes=[energy_axis],    dtype=float,)
_,ax,_=counts.sum_over_axes().smooth(2).plot(stretch="log", vmax=30);
 
## Lines to be added
#wcs = counts.geom.wcs
#src_pos = SkyCoord.from_name("Sgr A").galactic 
#ax.plot(src_pos.to_pixel(wcs=wcs)[0], src_pos.to_pixel(wcs=wcs)[1],"o", color="red")

# %%
# Combine the above plot with the aitoff, placing the above plot behind the aitoff.

# %%
ax=counts.sum_over_axes().smooth(2).plot(stretch="sqrt", vmax=30)
wcs = counts.geom.wcs
src_pos = SkyCoord.from_name("Sgr A").galactic 
ax.plot(src_pos.to_pixel(wcs=wcs)[0], src_pos.to_pixel(wcs=wcs)[1],"o", color="red")

# %%
pi = np.pi
deg2rad = pi/180.
ax = plt.figure(figsize=(10, 5))
im=plt.imread("/Users/danieldejesus/Downloads/FermiPulsarSkyMap.png")
ax = plt.subplot(111, projection='aitoff')
org=0
ax.imshow(im)
tick_xlabels = [r'$150^\circ$', r'$120^\circ$', r'$90^\circ$', r'$60^\circ$', r'$30^\circ$', 
                r'$0^\circ$', r'$330^\circ$', r'$300^\circ$', r'$270^\circ$', r'$240^\circ$', r'$210^\circ$']
ax.set_xticklabels(tick_xlabels)     # we add the scale on the x axis
#plt.set_xlabel(r'$l$')
#plt.xaxis.label.set_fontsize(16)
#plt.set_ylabel(r'$b$')
#plt.yaxis.label.set_fontsize(12)
ax.grid(True)
#plt.plot(x+np.pi/6,y+np.pi/6)
#plt.plot(x-np.pi/2,y-np.pi/2);

# Pass the coordinates in radians, since otherwise the
# aitoff projection messes up:

ax.plot(-1*psrtable['coord'].galactic.l.radian, psrtable['coord'].galactic.b.radian, '.', color=colors[0])
ax.plot(2*pi-psrtable['coord'].galactic.l.radian, psrtable['coord'].galactic.b.radian, '.', color=colors[0])
ax.plot(-1*FermiAssocghrss['coord'].galactic.l.radian, FermiAssocghrss['coord'].galactic.b.radian, 'o', color=colors[1],label="ghrss")
ax.plot(2*pi-FermiAssocghrss['coord'].galactic.l.radian, FermiAssocghrss['coord'].galactic.b.radian, 'o', color=colors[1])
ax.plot(-1*FermiAssoc['coord'].galactic.l.radian, FermiAssoc['coord'].galactic.b.radian, 'o', color=colors[2],label="ASSOC")
ax.plot(2*pi-FermiAssoc['coord'].galactic.l.radian, FermiAssoc['coord'].galactic.b.radian, 'o', color=colors[2])
ax.plot(-1*FermiBlind['coord'].galactic.l.radian, FermiBlind['coord'].galactic.b.radian, 'o', color=colors[3],label="Blind")
ax.plot(2*pi-FermiBlind['coord'].galactic.l.radian, FermiBlind['coord'].galactic.b.radian, 'o', color=colors[3])
plt.grid(True)
plt.text(0,-100*deg2rad,r'$l$',
      ha='center', va='center', fontsize=16)
#plt.xlabel(r'$l$', fontsize=16)
plt.ylabel(r'$b$', fontsize=16)
plt.legend(loc="upper right")
plt.show()

# %%
plt.imshow(im)

# %%
Set1=cm.get_cmap("Set1")
colors=Set1.colors
print(colors[0],colors[1])
colors=['grey',colors[1],colors[2],colors[3],colors[4]]

# %%
FermiAssoc=psrtable[psrtable['SURVEY']=='FermiAssoc']

# %%
pi = np.pi
deg2rad = pi/180.
ax = plt.figure(figsize=(10, 5))
ax = plt.subplot(111, projection='aitoff')
org=0
tick_xlabels = [r'$150^\circ$', r'$120^\circ$', r'$90^\circ$', r'$60^\circ$', r'$30^\circ$', 
                r'$0^\circ$', r'$330^\circ$', r'$300^\circ$', r'$270^\circ$', r'$240^\circ$', r'$210^\circ$']
ax.set_xticklabels(tick_xlabels)     # we add the scale on the x axis
#plt.set_xlabel(r'$l$')
#plt.xaxis.label.set_fontsize(16)
#plt.set_ylabel(r'$b$')
#plt.yaxis.label.set_fontsize(12)
ax.grid(True)
#plt.plot(x+np.pi/6,y+np.pi/6)
#plt.plot(x-np.pi/2,y-np.pi/2);

# Pass the coordinates in radians, since otherwise the
# aitoff projection messes up:

ax.plot(-1*psrtable['coord'].galactic.l.radian, psrtable['coord'].galactic.b.radian, '.', color=colors[0])
ax.plot(2*pi-psrtable['coord'].galactic.l.radian, psrtable['coord'].galactic.b.radian, '.', color=colors[0])
ax.plot(-1*FermiAssoc['coord'].galactic.l.radian, FermiAssoc['coord'].galactic.b.radian, 'o', color=colors[1])
ax.plot(2*pi-FermiAssoc['coord'].galactic.l.radian, FermiAssoc['coord'].galactic.b.radian, 'o', color=colors[1])
ax.plot
plt.grid(True)
plt.text(0,-100*deg2rad,r'$l$',
      ha='center', va='center', fontsize=16)
#plt.xlabel(r'$l$', fontsize=16)
plt.ylabel(r'$b$', fontsize=16)

plt.show()

# %%
Dark2=cm.get_cmap("Dark2")
colors=Dark2.colors
print(colors[0],colors[1])

# %%
FermiBlind=psrtable[psrtable['SURVEY']=='FermiBlind']

# %%
pi = np.pi
deg2rad = pi/180.
ax = plt.figure(figsize=(10, 5))
ax = plt.subplot(111, projection='aitoff')
org=0
tick_xlabels = [r'$150^\circ$', r'$120^\circ$', r'$90^\circ$', r'$60^\circ$', r'$30^\circ$', 
                r'$0^\circ$', r'$330^\circ$', r'$300^\circ$', r'$270^\circ$', r'$240^\circ$', r'$210^\circ$']
ax.set_xticklabels(tick_xlabels)     # we add the scale on the x axis
#plt.set_xlabel(r'$l$')
#plt.xaxis.label.set_fontsize(16)
#plt.set_ylabel(r'$b$')
#plt.yaxis.label.set_fontsize(12)
ax.grid(True)
#plt.plot(x+np.pi/6,y+np.pi/6)
#plt.plot(x-np.pi/2,y-np.pi/2);

# Pass the coordinates in radians, since otherwise the
# aitoff projection messes up:

ax.plot(-1*psrtable['coord'].galactic.l.radian, psrtable['coord'].galactic.b.radian, '.', color=colors[0])
ax.plot(2*pi-psrtable['coord'].galactic.l.radian, psrtable['coord'].galactic.b.radian, '.', color=colors[0])
ax.plot(-1*FermiBlind['coord'].galactic.l.radian, FermiBlind['coord'].galactic.b.radian, 'o', color=colors[1])
ax.plot(2*pi-FermiBlind['coord'].galactic.l.radian, FermiBlind['coord'].galactic.b.radian, 'o', color=colors[1])
ax.plot
plt.grid(True)
plt.text(0,-100*deg2rad,r'$l$',
      ha='center', va='center', fontsize=16)
#plt.xlabel(r'$l$', fontsize=16)
plt.ylabel(r'$b$', fontsize=16)

plt.show()

# %%
pi = np.pi
deg2rad = pi/180.
ax = plt.figure(figsize=(10, 5))
ax = plt.subplot(111, projection='aitoff',label='FermiAssoc')
org=0
tick_xlabels = [r'$150^\circ$', r'$120^\circ$', r'$90^\circ$', r'$60^\circ$', r'$30^\circ$', 
                r'$0^\circ$', r'$330^\circ$', r'$300^\circ$', r'$270^\circ$', r'$240^\circ$', r'$210^\circ$']
ax.set_xticklabels(tick_xlabels)     # we add the scale on the x axis
#plt.set_xlabel(r'$l$')
#plt.xaxis.label.set_fontsize(16)
#plt.set_ylabel(r'$b$')
#plt.yaxis.label.set_fontsize(12)
ax.grid(True)
#plt.plot(x+np.pi/6,y+np.pi/6)
#plt.plot(x-np.pi/2,y-np.pi/2);

# Pass the coordinates in radians, since otherwise the
# aitoff projection messes up:

ax.plot(-1*psrtable['coord'].galactic.l.radian, psrtable['coord'].galactic.b.radian, '.', color=colors[0],
       label='FermiAssoc')
ax.plot(2*pi-psrtable['coord'].galactic.l.radian, psrtable['coord'].galactic.b.radian, '.', color=colors[0],
       label='FermiAssoc')
ax.plot(-1*FermiAssoc['coord'].galactic.l.radian, FermiAssoc['coord'].galactic.b.radian, 'o', color=colors[1],
       label='FermiAssoc')
ax.plot(2*pi-FermiAssoc['coord'].galactic.l.radian, FermiAssoc['coord'].galactic.b.radian, 'o', color=colors[1],
       label='FermiAssoc')
ax.plot
plt.grid(True)
plt.text(0,-100*deg2rad,r'$l$',
      ha='center', va='center', fontsize=16)
#plt.xlabel(r'$l$', fontsize=16)
plt.ylabel(r'$b$', fontsize=16)

plt.show()
legend = ax.legend(loc=(0.0, 1.1))

# %%
gc_pos = SkyCoord(0, 0, unit="deg", frame="galactic")
energy_axis = MapAxis.from_edges(
    [1e4, 3e4, 1e5, 3e5, 2e6], name="energy", unit="MeV", interp="log"
)
counts = Map.create(
    skydir=gc_pos,
    npix=(100, 80),
    proj="TAN",
    frame="galactic",
    binsz=0.1,
    axes=[energy_axis],
    dtype=float,
)
# We put this call into the same Jupyter cell as the Map.create
# because otherwise we could accidentally fill the counts
# multiple times when executing the ``fill_by_coord`` multiple times.

# %%
gc_pos = SkyCoord(0, 0, unit="deg", frame="galactic")
energy_axis = MapAxis.from_edges(
    [1e4, 3e4, 1e5, 3e5, 2e6], name="energy", unit="MeV", interp="log"
)
counts = Map.create(
    skydir=gc_pos,
    npix=(3600, 1800),
    proj="AIT",
    frame="galactic",
    binsz=0.1,
    axes=[energy_axis],
    dtype=float,
)
# We put this call into the same Jupyter cell as the Map.create
# because otherwise we could accidentally fill the counts
# multiple times when executing the ``fill_by_coord`` multiple times.
counts.fill_by_coord({"skycoord": events.radec, "energy": events.energy})

pi = np.pi
deg2rad = pi/180.
ax = plt.figure(figsize=(10, 5))
ax = plt.subplot(111, projection='aitoff')
org=0
tick_xlabels = [r'$150^\circ$', r'$120^\circ$', r'$90^\circ$', r'$60^\circ$', r'$30^\circ$', 
                r'$0^\circ$', r'$330^\circ$', r'$300^\circ$', r'$270^\circ$', r'$240^\circ$', r'$210^\circ$']
ax.set_xticklabels(tick_xlabels)     # we add the scale on the x axis
#plt.set_xlabel(r'$l$')
#plt.xaxis.label.set_fontsize(16)
#plt.set_ylabel(r'$b$')
#plt.yaxis.label.set_fontsize(12)
ax.grid(True)
#plt.plot(x+np.pi/6,y+np.pi/6)
#plt.plot(x-np.pi/2,y-np.pi/2);

# Pass the coordinates in radians, since otherwise the
# aitoff projection messes up:

ax.plot(-1*psrtable['coord'].galactic.l.radian, psrtable['coord'].galactic.b.radian, '.', color=colors[0])
ax.plot(2*pi-psrtable['coord'].galactic.l.radian, psrtable['coord'].galactic.b.radian, '.', color=colors[0])
ax.plot(-1*FermiAssocghrss['coord'].galactic.l.radian, FermiAssocghrss['coord'].galactic.b.radian, 'o', color=colors[1],label="ghrss")
ax.plot(2*pi-FermiAssocghrss['coord'].galactic.l.radian, FermiAssocghrss['coord'].galactic.b.radian, 'o', color=colors[1])
ax.plot(-1*FermiAssoc['coord'].galactic.l.radian, FermiAssoc['coord'].galactic.b.radian, 'o', color=colors[2],label="ASSOC")
ax.plot(2*pi-FermiAssoc['coord'].galactic.l.radian, FermiAssoc['coord'].galactic.b.radian, 'o', color=colors[2])
ax.plot(-1*FermiBlind['coord'].galactic.l.radian, FermiBlind['coord'].galactic.b.radian, 'o', color=colors[3],label="Blind")
ax.plot(2*pi-FermiBlind['coord'].galactic.l.radian, FermiBlind['coord'].galactic.b.radian, 'o', color=colors[3])
plt.grid(True)
plt.text(0,-100*deg2rad,r'$l$',
      ha='center', va='center', fontsize=16)
#plt.xlabel(r'$l$', fontsize=16)
plt.ylabel(r'$b$', fontsize=16)
plt.legend(loc="upper right")
plt.show()

# %%
pi = np.pi
deg2rad = pi/180.
ax = plt.figure(figsize=(10, 5))
ax = plt.subplot(111, projection='aitoff')
org=0
tick_xlabels = [r'$150^\circ$', r'$120^\circ$', r'$90^\circ$', r'$60^\circ$', r'$30^\circ$', 
                r'$0^\circ$', r'$330^\circ$', r'$300^\circ$', r'$270^\circ$', r'$240^\circ$', r'$210^\circ$']
ax.set_xticklabels(tick_xlabels)     # we add the scale on the x axis
#plt.set_xlabel(r'$l$')
#plt.xaxis.label.set_fontsize(16)
#plt.set_ylabel(r'$b$')
#plt.yaxis.label.set_fontsize(12)
ax.grid(True)
#plt.plot(x+np.pi/6,y+np.pi/6)
#plt.plot(x-np.pi/2,y-np.pi/2);

# Pass the coordinates in radians, since otherwise the
# aitoff projection messes up:

ax.plot(-1*psrtable['coord'].galactic.l.radian, psrtable['coord'].galactic.b.radian, '.', color=colors[0],counts = Map.create(
    skydir=gc_pos,
    npix=(3600, 1800),
    proj="AIT",
    frame="galactic",
    binsz=0.1,
    axes=[energy_axis],
    dtype=float,
))
ax.plot(2*pi-psrtable['coord'].galactic.l.radian, psrtable['coord'].galactic.b.radian, '.', color=colors[0])
ax.plot(-1*FermiAssocghrss['coord'].galactic.l.radian, FermiAssocghrss['coord'].galactic.b.radian, 'o', color=colors[1],label="ghrss")
ax.plot(2*pi-FermiAssocghrss['coord'].galactic.l.radian, FermiAssocghrss['coord'].galactic.b.radian, 'o', color=colors[1])
ax.plot(-1*FermiAssoc['coord'].galactic.l.radian, FermiAssoc['coord'].galactic.b.radian, 'o', color=colors[2],label="ASSOC")
ax.plot(2*pi-FermiAssoc['coord'].galactic.l.radian, FermiAssoc['coord'].galactic.b.radian, 'o', color=colors[2])
ax.plot(-1*FermiBlind['coord'].galactic.l.radian, FermiBlind['coord'].galactic.b.radian, 'o', color=colors[3],label="Blind")
ax.plot(2*pi-FermiBlind['coord'].galactic.l.radian, FermiBlind['coord'].galactic.b.radian, 'o', color=colors[3])
plt.grid(True)
plt.text(0,-100*deg2rad,r'$l$',
      ha='center', va='center', fontsize=16)
#plt.xlabel(r'$l$', fontsize=16)
plt.ylabel(r'$b$', fontsize=16)
plt.legend(loc="upper right")
plt.show()

# %%
from astropy import units as u
from astropy.coordinates import SkyCoord
from gammapy.data import EventList
from gammapy.datasets import MapDataset
from gammapy.datasets.map import MapEvaluator
from gammapy.irf import EnergyDependentTablePSF, PSFMap, EDispMap
from gammapy.maps import Map, MapAxis, WcsNDMap, WcsGeom
from gammapy.modeling.models import (
    PowerLawSpectralModel,
    PointSpatialModel,
    SkyModel,
    SkyDiffuseCube,
    Models,
    create_fermi_isotropic_diffuse_model,
    BackgroundModel,
)
from gammapy.modeling import Fit

# %%
exposure = WcsNDMap(geom, data, unit=exposure_hpx.unit, dtype=float)
print(exposure.geom)
print(exposure.geom.axes[0])
